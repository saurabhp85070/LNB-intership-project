# %% [markdown]
# ## Wine quality prediction

# %%
# import pandas
import pandas as pd

# import numpy
import numpy as np

# import seaborn
import seaborn as sb

# import matplotlib
import matplotlib.pyplot as plt

# %%
url="https://drive.google.com/file/d/1Nc8Dnftmy3giLGwUsTD-9g143cMHk-4P/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
df.head(30)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# 12  white            7.9              0.18         0.37            1.20
# 13  white            6.6              0.16         0.40            1.50
# 14  white            8.3              0.42         0.62           19.25
# 15  white            6.6              0.17         0.38            1.50
# 16  white            6.3              0.48         0.04            1.10
# 17  white            NaN              0.66         0.48            1.20
# 18  white            7.4              0.34         0.42            1.10
# 19  white            6.5              0.31         0.14            7.50
# 20  white            6.2              0.66         0.48            1.20
# 21  white            6.4              0.31         0.38            2.90
# 22  white            6.8              0.26         0.42            1.70
# 23  white            7.6              0.67         0.14            1.50
# 24  white            6.6              0.27         0.41            1.30
# 25  white            7.0              0.25         0.32            9.00
# 26  white            6.9              0.24         0.35            1.00
# 27  white            7.0              0.28         0.39            8.70
# 28  white            7.4              0.27         0.48            1.10
# 29  white            7.2              0.32         0.36            2.00
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0       0.045                 45.0                 170.0   1.0010  3.00
# 1       0.049                 14.0                 132.0   0.9940  3.30
# 2       0.050                 30.0                  97.0   0.9951  3.26
# 3       0.058                 47.0                 186.0   0.9956  3.19
# 4       0.058                 47.0                 186.0   0.9956  3.19
# 5       0.050                 30.0                  97.0   0.9951  3.26
# 6       0.045                 30.0                 136.0   0.9949  3.18
# 7       0.045                 45.0                 170.0   1.0010  3.00
# 8       0.049                 14.0                 132.0   0.9940  3.30
# 9       0.044                 28.0                 129.0   0.9938  3.22
# 10      0.033                 11.0                  63.0   0.9908  2.99
# 11      0.035                 17.0                 109.0   0.9947  3.14
# 12      0.040                 16.0                  75.0   0.9920  3.18
# 13      0.044                 48.0                 143.0   0.9912  3.54
# 14      0.040                 41.0                 172.0   1.0002  2.98
# 15      0.032                 28.0                 112.0   0.9914  3.25
# 16      0.046                 30.0                  99.0   0.9928  3.24
# 17      0.029                 29.0                  75.0   0.9892  3.33
# 18      0.033                 17.0                 171.0   0.9917  3.12
# 19      0.044                 34.0                 133.0   0.9955  3.22
# 20      0.029                 29.0                  75.0   0.9892  3.33
# 21      0.038                 19.0                 102.0   0.9912  3.17
# 22      0.049                 41.0                 122.0   0.9930  3.47
# 23      0.074                 25.0                 168.0   0.9937  3.05
# 24      0.052                 16.0                 142.0   0.9951  3.42
# 25      0.046                 56.0                 245.0   0.9955  3.25
# 26      0.052                 35.0                 146.0   0.9930  3.45
# 27      0.051                 32.0                 141.0   0.9961  3.38
# 28      0.047                 17.0                 132.0   0.9914  3.19
# 29      0.033                 37.0                 114.0   0.9906  3.10
#
#     sulphates  alcohol  quality
# 0        0.45      8.8        6
# 1        0.49      9.5        6
# 2        0.44     10.1        6
# 3        0.40      9.9        6
# 4        0.40      9.9        6
# 5        0.44     10.1        6
# 6        0.47      9.6        6
# 7        0.45      8.8        6
# 8        0.49      9.5        6
# 9        0.45     11.0        6
# 10       0.56     12.0        5
# 11       0.53      9.7        5
# 12       0.63     10.8        5
# 13       0.52     12.4        7
# 14       0.67      9.7        5
# 15       0.55     11.4        7
# 16       0.36      9.6        6
# 17       0.39     12.8        8
# 18       0.53     11.3        6
# 19       0.50      9.5        5
# 20       0.39     12.8        8
# 21       0.35     11.0        7
# 22       0.48     10.5        8
# 23       0.51      9.3        5
# 24       0.47     10.0        6
# 25       0.50     10.4        6
# 26       0.44     10.0        6
# 27       0.53     10.5        6
# 28       0.49     11.6        6
# 29       0.71     12.3        7

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
plt.figure(figsize=[10,6])
# plot bar graph
plt.bar(df['quality'],df['alcohol'],color='red')
# label x-axis
plt.xlabel('quality')
#label y-axis
plt.ylabel('alcohol')
# Out:
# Text(0, 0.5, 'alcohol')

# %%
# ploting heatmap
plt.figure(figsize=[19,10],facecolor='blue')
sb.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
for a in range(len(df.corr().columns)):
    for b in range(a):
        if abs(df.corr().iloc[a,b]) >0.7:
            name = df.corr().columns[a]
            print(name)
# Out:
# total sulfur dioxide

# %%
new_df=df.drop('total sulfur dioxide',axis=1)

# %%
new_df.isnull().sum()
# Out:
# type                    0
# fixed acidity          10
# volatile acidity        8
# citric acid             3
# residual sugar          2
# chlorides               2
# free sulfur dioxide     0
# density                 0
# pH                      9
# sulphates               4
# alcohol                 0
# quality                 0
# dtype: int64

# %%
new_df.update(new_df.fillna(new_df.mean()))
# Out:
# C:\Users\SAURAB~1\AppData\Local\Temp/ipykernel_11852/1435263875.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_df.update(new_df.fillna(new_df.mean()))

# %%
# no of categorical columns
cat = new_df.select_dtypes(include='O')
# create dummies of categorical columns
df_dummies = pd.get_dummies(new_df,drop_first = True)
df_dummies
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  density    pH  sulphates  alcohol  quality  \
# 0                    45.0  1.00100  3.00   0.450000      8.8        6
# 1                    14.0  0.99400  3.30   0.490000      9.5        6
# 2                    30.0  0.99510  3.26   0.440000     10.1        6
# 3                    47.0  0.99560  3.19   0.400000      9.9        6
# 4                    47.0  0.99560  3.19   0.400000      9.9        6
# ...                   ...      ...   ...        ...      ...      ...
# 6492                 32.0  0.99490  3.45   0.580000     10.5        5
# 6493                 39.0  0.99512  3.52   0.531215     11.2        6
# 6494                 29.0  0.99574  3.42   0.750000     11.0        6
# 6495                 32.0  0.99547  3.57   0.710000     10.2        5
# 6496                 18.0  0.99549  3.39   0.660000     11.0        6
#
#       type_white
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 6492           0
# 6493           0
# 6494           0
# 6495           0
# 6496           0
#
# [6497 rows x 12 columns]

# %%
df_dummies['best quality']=[1 if x>=7 else 0 for x in df.quality]
df_dummies
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  density    pH  sulphates  alcohol  quality  \
# 0                    45.0  1.00100  3.00   0.450000      8.8        6
# 1                    14.0  0.99400  3.30   0.490000      9.5        6
# 2                    30.0  0.99510  3.26   0.440000     10.1        6
# 3                    47.0  0.99560  3.19   0.400000      9.9        6
# 4                    47.0  0.99560  3.19   0.400000      9.9        6
# ...                   ...      ...   ...        ...      ...      ...
# 6492                 32.0  0.99490  3.45   0.580000     10.5        5
# 6493                 39.0  0.99512  3.52   0.531215     11.2        6
# 6494                 29.0  0.99574  3.42   0.750000     11.0        6
# 6495                 32.0  0.99547  3.57   0.710000     10.2        5
# 6496                 18.0  0.99549  3.39   0.660000     11.0        6
#
#       type_white  best quality
# 0              1             0
# 1              1             0
# 2              1             0
# 3              1             0
# 4              1             0
# ...          ...           ...
# 6492           0             0
# 6493           0             0
# 6494           0             0
# 6495           0             0
# 6496           0             0
#
# [6497 rows x 13 columns]

# %%
# import libraries
from sklearn.model_selection import train_test_split

# independent variables
x = df_dummies.drop(['quality','best quality'],axis=1)
# dependent variable
y = df_dummies['best quality']

# creating train test splits
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)

# %%
print(type(x_test))
x_test
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 369             7.1              0.39         0.35            12.5      0.044
# 6243            8.2              0.44         0.24             2.3      0.063
# 3374            5.9              0.19         0.21             1.7      0.045
# 1009            8.3              0.15         0.39             1.3      0.055
# 220             7.5              0.27         0.36             7.0      0.036
# ...             ...               ...          ...             ...        ...
# 1757            6.9              0.29         0.23             8.6      0.056
# 5699            8.6              0.55         0.09             3.3      0.068
# 3875            7.4              0.22         0.27             1.6      0.057
# 5584            7.1              0.65         0.18             1.8      0.070
# 884             6.8              0.23         0.29            12.2      0.035
#
#       free sulfur dioxide  density    pH  sulphates  alcohol  type_white
# 369                  26.0  0.99410  3.17       0.29     11.6           1
# 6243                 10.0  0.99613  3.25       0.53     10.2           0
# 3374                 57.0  0.99341  3.32       0.44      9.5           1
# 1009                 32.0  0.99300  3.08       0.39     10.5           1
# 220                  45.0  0.99390  3.03       0.33     11.0           1
# ...                   ...      ...   ...        ...      ...         ...
# 1757                 56.0  0.99670  3.17       0.44      8.8           1
# 5699                  8.0  0.99735  3.23       0.44     10.0           0
# 3875                 45.0  0.99299  3.29       0.44      9.9           1
# 5584                 13.0  0.99700  3.44       0.60      9.1           0
# 884                  38.0  0.99760  3.35       0.52      9.8           1
#
# [1300 rows x 11 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

rnd = RandomForestClassifier()
rnd.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rnd.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred, y_test)
print("Accuracy", score)
# Out:
# Accuracy 0.8761538461538462

# %% [markdown]
# ### Saving model

# %%
# saving model
import pickle

with open("./SavedModels/model6","wb") as f:
    pickle.dump(rnd,f)

# %%
# loading saved model
with open("./SavedModels/model6","rb") as f:
    lr=pickle.load(f)

# %%
lr.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 369             7.1              0.39         0.35            12.5      0.044
# 6243            8.2              0.44         0.24             2.3      0.063
# 3374            5.9              0.19         0.21             1.7      0.045
# 1009            8.3              0.15         0.39             1.3      0.055
# 220             7.5              0.27         0.36             7.0      0.036
# ...             ...               ...          ...             ...        ...
# 1757            6.9              0.29         0.23             8.6      0.056
# 5699            8.6              0.55         0.09             3.3      0.068
# 3875            7.4              0.22         0.27             1.6      0.057
# 5584            7.1              0.65         0.18             1.8      0.070
# 884             6.8              0.23         0.29            12.2      0.035
#
#       free sulfur dioxide  density    pH  sulphates  alcohol  type_white
# 369                  26.0  0.99410  3.17       0.29     11.6           1
# 6243                 10.0  0.99613  3.25       0.53     10.2           0
# 3374                 57.0  0.99341  3.32       0.44      9.5           1
# 1009                 32.0  0.99300  3.08       0.39     10.5           1
# 220                  45.0  0.99390  3.03       0.33     11.0           1
# ...                   ...      ...   ...        ...      ...         ...
# 1757                 56.0  0.99670  3.17       0.44      8.8           1
# 5699                  8.0  0.99735  3.23       0.44     10.0           0
# 3875                 45.0  0.99299  3.29       0.44      9.9           1
# 5584                 13.0  0.99700  3.44       0.60      9.1           0
# 884                  38.0  0.99760  3.35       0.52      9.8           1
#
# [1300 rows x 11 columns]

# %%
fa=float(input("Enter fixed acidity: "))
va=float(input("Enter volatile acidity: "))
ca=float(input("Enter citric acid: "))
rs=float(input("Enter residual sugar: "))
cl=float(input("Enter chlorides: "))
fsd=float(input("Enter free sulfur dioxide: "))
# tsd=float(input("Enter total sulfur dioxide: "))
den=float(input("Enter density: "))
ph=float(input("Enter pH: "))
sulp=float(input("Enter sulphates: "))
ol=float(input("Enter alcohol: "))
wt=int(input("Enter wine type(Red=0,White=1): "))
# Out:
# Enter fixed acidity: 6.2
# Enter volatile acidity: 0.600
# Enter citric acid: 0.08
# Enter residual sugar: 2.0
# Enter chlorides: 0.090
# Enter free sulfur dioxide: 32.0
# Enter density: 0.99490
# Enter pH: 3.45
# Enter sulphates: 0.58
# Enter alcohol: 10.5
# Enter wine type(Red=0,White=1): 0

# %%
lst=[[fa,va,ca,rs,cl,fsd,den,ph,sulp,ol,wt]]
lst
# Out:
# [[6.2, 0.6, 0.08, 2.0, 0.09, 32.0, 0.9949, 3.45, 0.58, 10.5, 0]]

# %%
value=lr.predict(lst)
value
# Out:
# d:\programs\python\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
if value==1:
    print("Prediction: Good")
else:
    print("Prediction: Bad")
# Out:
# Prediction: Bad
