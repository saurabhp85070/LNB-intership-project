# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url="https://drive.google.com/file/d/1-n2gw42FWs0VdtqqvweiOg8O6FOczdan/view?usp=sharing"
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df=pd.read_csv(url)

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.count()
# Out:
# datetime      10886
# season        10886
# holiday       10886
# workingday    10886
# weather       10886
# temp          10886
# atemp         10886
# humidity      10886
# windspeed     10886
# casual        10886
# registered    10886
# count         10886
# dtype: int64

# %%
sns.distplot(df['count'])
# Out:
# d:\programs\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='count', ylabel='Density'>

# %%
print("Skewness:",df['count'].skew())
print("Kurtosis:",df['count'].kurt())
# Out:
# Skewness: 1.2420662117180776
# Kurtosis: 1.3000929518398334

# %%
temp= pd.DatetimeIndex(df['datetime'])
df["dayofweek"] = temp.dayofweek
df["hour"] = temp.hour
df["month"] = temp.month
df['year']= temp.year
df = df.drop(['datetime'],axis=1)
df.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    casual  registered  count  dayofweek  hour  month  year
# 0       3          13     16          5     0      1  2011
# 1       8          32     40          5     1      1  2011
# 2       5          27     32          5     2      1  2011
# 3       3          10     13          5     3      1  2011
# 4       0           1      1          5     4      1  2011

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count     dayofweek          hour         month          year
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean     191.574132      3.013963     11.541613      6.521495   2011.501929
# std      181.144454      2.004585      6.915838      3.444373      0.500019
# min        1.000000      0.000000      0.000000      1.000000   2011.000000
# 25%       42.000000      1.000000      6.000000      4.000000   2011.000000
# 50%      145.000000      3.000000     12.000000      7.000000   2012.000000
# 75%      284.000000      5.000000     18.000000     10.000000   2012.000000
# max      977.000000      6.000000     23.000000     12.000000   2012.000000

# %%
sns.set()
cols = ['count', 'registered', 'casual', 'temp', 'atemp', 'season','dayofweek','hour','month','year']
sns.pairplot(df[cols],size=2.5)
plt.show()
# Out:
# d:\programs\python\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
corrmat = df.corr()
sns.heatmap(corrmat)
# Out:
# <AxesSubplot:>

# %%
k =10
cols = corrmat.nlargest(k,'count')['count'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm,cbar=True,square=True,annot=True,fmt='.2f',annot_kws={'size':10},yticklabels=cols.values,xticklabels=cols.values)
plt.show()

# %%
#scatter plot registered/count

var ='registered'
data = pd.concat([df['count'],df[var]],axis=1)
data.plot.scatter(x=var,y='count')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='registered', ylabel='count'>

# %%
#scatter plot casual/count

var ='casual'
data = pd.concat([df['count'],df[var]],axis=1)
data.plot.scatter(x=var,y='count')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='casual', ylabel='count'>

# %%
#box plot season/count

var ='season'
data =pd.concat([df['count'],df[var]],axis=1)
f,ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x='season',y='count',data=data)

# %%
var ='holiday'
data =pd.concat([df['count'],df[var]],axis=1)
f,ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var,y='count',data=data)

# %%
#box plot workingday/count

var ='workingday'
data =pd.concat([df['count'],df[var]],axis=1)
f,ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var,y='count',data=data)

# %%
#box plot weather/count

var ='weather'
data =pd.concat([df['count'],df[var]],axis=1)
f,ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x=var,y='count',data=data)

# %%
#histogram and normal probability plot
from scipy.stats import norm
from scipy import stats


sns.distplot(df['count'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['count'], plot=plt)
# Out:
# d:\programs\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['count'] = np.log(df['count'])

# %%
sns.distplot(df['count'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['count'], plot=plt)
# Out:
# d:\programs\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import StandardScaler
count_scaled = StandardScaler().fit_transform(df['count'][:,np.newaxis])
lowrange = count_scaled[count_scaled[:,0].argsort()][:10]
highrange = count_scaled[count_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(lowrange)
print('\nouter range (high) of the distribution:')
print(highrange)
# Out:
# outer range (low) of the distribution:
# [[-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]
#  [-3.05751461]]
#
# outer range (high) of the distribution:
# [[1.50875308]
#  [1.5109955 ]
#  [1.51174131]
#  [1.52356301]
#  [1.52939674]
#  [1.54234024]
#  [1.54589182]
#  [1.55991328]
#  [1.56129946]
#  [1.56612867]]
# C:\Users\SAURAB~1\AppData\Local\Temp/ipykernel_11596/1918838227.py:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   count_scaled = StandardScaler().fit_transform(df['count'][:,np.newaxis])

# %%
sns.distplot(df['count'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['count'], plot=plt)
# Out:
# d:\programs\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
y = df['count']
df = df.drop(['count','casual','registered'],axis=1)
df.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    dayofweek  hour  month  year
# 0          5     0      1  2011
# 1          5     1      1  2011
# 2          5     2      1  2011
# 3          5     3      1  2011
# 4          5     4      1  2011

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df,y,test_size=0.3,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7620, 12)
# (3266, 12)
# (7620,)
# (3266,)

# %%
print(type(x_test))
x_test
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 3133       3        0           1        1  33.62  40.150        59
# 5786       1        1           0        1   4.10   6.820        54
# 5224       4        0           0        1   9.84  11.365        48
# 8953       3        0           1        2  29.52  34.090        62
# 8054       2        0           1        1  25.42  31.060        53
# ...      ...      ...         ...      ...    ...     ...       ...
# 5527       1        0           1        2   9.84  12.880        52
# 7417       2        0           1        2  23.78  27.275        68
# 5700       1        0           1        1  18.86  22.725        67
# 8303       3        0           0        1  33.62  41.665        63
# 411        1        0           1        3   9.02  11.365        93
#
#       windspeed  dayofweek  hour  month  year
# 3133     0.0000          1    11      7  2011
# 5786     6.0032          0     6      1  2012
# 5224    12.9980          6    18     12  2011
# 8953    12.9980          2    10      8  2012
# 8054    16.9979          4    23      6  2012
# ...         ...        ...   ...    ...   ...
# 5527     6.0032          3    10      1  2012
# 7417    27.9993          1    10      5  2012
# 5700    12.9980          3    16      1  2012
# 8303    12.9980          5     8      7  2012
# 411      8.9981          2     4      1  2011
#
# [3266 rows x 12 columns]

# %%
x_train
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 613         1        0           1        1   9.02   9.090        32
# 4030        3        0           0        1  22.14  25.760        68
# 3582        3        0           1        1  26.24  28.790        83
# 10101       4        0           1        1   9.02  11.365        69
# 1430        2        0           1        3  13.12  14.395        81
# ...       ...      ...         ...      ...    ...     ...       ...
# 5734        1        0           0        1   6.56   8.335        47
# 5191        4        0           0        1  11.48  12.880        61
# 5390        4        0           0        1  11.48  13.635        48
# 860         1        0           0        1  15.58  19.695        17
# 7270        2        0           1        2  22.14  25.760        88
#
#        windspeed  dayofweek  hour  month  year
# 613      39.0007          1    17      2  2011
# 4030     12.9980          6    23      9  2011
# 3582      0.0000          4     4      8  2011
# 10101     8.9981          1     6     11  2012
# 1430     30.0026          1    11      4  2011
# ...          ...        ...   ...    ...   ...
# 5734     11.0014          5     2      1  2012
# 5191     19.0012          5     9     12  2011
# 5390     16.9979          6    16     12  2011
# 860      35.0008          5     7      2  2011
# 7270     12.9980          2     7      5  2012
#
# [7620 rows x 12 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import roc_auc_score, r2_score, mean_absolute_error,mean_squared_error

clf = DecisionTreeRegressor(random_state=0)
training = clf.fit(x_train,y_train)
prediction = clf.predict(x_test)
print("R2 Score:",r2_score(y_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediction))
print("Mean Squared Error:",mean_squared_error(y_test,prediction))
# Out:
# R2 Score: 0.8975882035795477
# Mean Absolute Error: 0.302095553823069
# Mean Squared Error: 0.2238860255059839

# %%
from sklearn.ensemble import AdaBoostRegressor

clf = AdaBoostRegressor(DecisionTreeRegressor(random_state=42))
training = clf.fit(x_train,y_train)
prediction = clf.predict(x_test)
print("R2 Score:",r2_score(y_test,prediction))
print("Mean Absolute Error:",mean_absolute_error(y_test,prediction))
print("Mean Squared Error:",mean_squared_error(y_test,prediction))
# Out:
# R2 Score: 0.9417371115034905
# Mean Absolute Error: 0.2235815073715459
# Mean Squared Error: 0.1273705471040522

# %%
prediction
# Out:
# array([4.85203026, 1.60943791, 4.92725369, ..., 5.44241771, 5.19849703,
#        0.        ])

# %%
# saving model
import pickle

with open("./SavedModels/model7","wb") as f:
    pickle.dump(clf,f)

# %%
# loading saved model
with open("./SavedModels/model7","rb") as f:
    lr=pickle.load(f)

# %%
x_test
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 3133       3        0           1        1  33.62  40.150        59
# 5786       1        1           0        1   4.10   6.820        54
# 5224       4        0           0        1   9.84  11.365        48
# 8953       3        0           1        2  29.52  34.090        62
# 8054       2        0           1        1  25.42  31.060        53
# ...      ...      ...         ...      ...    ...     ...       ...
# 5527       1        0           1        2   9.84  12.880        52
# 7417       2        0           1        2  23.78  27.275        68
# 5700       1        0           1        1  18.86  22.725        67
# 8303       3        0           0        1  33.62  41.665        63
# 411        1        0           1        3   9.02  11.365        93
#
#       windspeed  dayofweek  hour  month  year
# 3133     0.0000          1    11      7  2011
# 5786     6.0032          0     6      1  2012
# 5224    12.9980          6    18     12  2011
# 8953    12.9980          2    10      8  2012
# 8054    16.9979          4    23      6  2012
# ...         ...        ...   ...    ...   ...
# 5527     6.0032          3    10      1  2012
# 7417    27.9993          1    10      5  2012
# 5700    12.9980          3    16      1  2012
# 8303    12.9980          5     8      7  2012
# 411      8.9981          2     4      1  2011
#
# [3266 rows x 12 columns]

# %%
season=int(input("Enter Season ( 1 = spring, 2 = summer, 3 = fall, 4 = winter ): "))
hldy=int(input("Enter holiday( 1 = Yes , 0 = No ): "))
wrkdy=int(input("Enter workingday( 1 = Yes , 0 = No ): "))
print("""\n1: Clear, Few clouds, Partly cloudy, Partly cloudy\n 
            2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist\n
                3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds\n
                    4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog \n""")
wthr=int(input("Enter weather( 1 2 3 4): "))
temp=float(input("Enter temperature in Celsius: "))
atemp=float(input("Enter 'feels like' temperature in Celsius"))
humd=int(input("Enter relative humidity: "))
wndspd=float(input("Enter wind speed: "))
dow=int(input("Enter day of week: "))
hr=int(input("Enter Hour: "))
mon=int(input("Enter Month(MM): "))
yr=int(input("Enter year(YYYY): "))
# Out:
# Enter Season ( 1 = spring, 2 = summer, 3 = fall, 4 = winter ): 3
# Enter holiday( 1 = Yes , 0 = No ): 0
# Enter workingday( 1 = Yes , 0 = No ): 1
# 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#
#             2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#
#                 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#                     4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# Enter weather( 1 2 3 4): 1
# Enter temperature in Celsius: 33.62
# Enter 'feels like' temperature in Celsius40.150
# Enter relative humidity: 59
# Enter wind speed: 0.0000
# Enter day of week: 1
# Enter Hour: 11
# Enter Month(MM): 7
# Enter year(YYYY): 2011

# %%
lst=[[season,hldy,wrkdy,wthr,temp,atemp,humd,wndspd,dow,hr,mon,yr]]
lst
# Out:
# [[3, 0, 1, 1, 33.62, 40.15, 59, 0.0, 1, 11, 7, 2011]]

# %%
lr.predict(lst)
# Out:
# d:\programs\python\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([4.85203026])
